# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Importing data

# %%
data = pd.read_csv('Metro_House_Rent.csv')

# %%
data
# Out:
#             city              area  rooms  bathroom  parking_spaces floor  \
# 0      Bangalore       Brookefield      2         2               1     8
# 1          Delhi  Rohini sector 16      3         2               2    10
# 2      Bangalore      Haralur Road      3         2               0     -
# 3         Mumbai       Mulund East      2         2               1     -
# 4      Bangalore    Sarjapur  Road      2         2               1     1
# ...          ...               ...    ...       ...             ...   ...
# 10687  Bangalore        Whitefield      1         2               1     9
# 10688    Kolkata            Howrah      2         2               1     4
# 10689    Kolkata     Bangur avenue      1         1               0     1
# 10690  Bangalore       Tumkur Road      3         4               3     4
# 10691  Bangalore      Rajaji Nagar      3         2               1     2
#
#       animal_allowance      furniture  association_tax  rent_amount  \
# ...

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#             city              area  rooms  bathroom  parking_spaces floor  \
# 0      Bangalore       Brookefield      2         2               1     8
# 1          Delhi  Rohini sector 16      3         2               2    10
# 2      Bangalore      Haralur Road      3         2               0     -
# 3         Mumbai       Mulund East      2         2               1     -
# 4      Bangalore    Sarjapur  Road      2         2               1     1
# ...          ...               ...    ...       ...             ...   ...
# 10687  Bangalore        Whitefield      1         2               1     9
# 10688    Kolkata            Howrah      2         2               1     4
# 10689    Kolkata     Bangur avenue      1         1               0     1
# 10690  Bangalore       Tumkur Road      3         4               3     4
# 10691  Bangalore      Rajaji Nagar      3         2               1     2
#
#       animal_allowance      furniture  association_tax  rent_amount  \
# ...

# %% [markdown]
# # Cheking data Information

# %%
# To check how many rows and columns present in dataset.
df.shape
# Out:
# (10692, 13)

# %%
df.columns
# Out:
# Index(['city', 'area', 'rooms', 'bathroom', 'parking_spaces', 'floor',
#        'animal_allowance', 'furniture', 'association_tax', 'rent_amount',
#        'property_tax', 'fire_insurance', 'total_rent'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10692 entries, 0 to 10691
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   city              10692 non-null  object
#  1   area              10692 non-null  object
#  2   rooms             10692 non-null  int64
#  3   bathroom          10692 non-null  int64
#  4   parking_spaces    10692 non-null  int64
#  5   floor             10692 non-null  object
#  6   animal_allowance  10692 non-null  object
#  7   furniture         10692 non-null  object
#  8   association_tax   10692 non-null  int64
#  9   rent_amount       10692 non-null  int64
#  10  property_tax      10692 non-null  int64
#  11  fire_insurance    10692 non-null  int64
#  12  total_rent        10692 non-null  int64
# dtypes: int64(8), object(5)
# memory usage: 1.1+ MB

# %%
# To check data of how many cities we have (City Numbers)
df.city.nunique()
# Out:
# 5

# %%
# To check data of how many cities we have (City Names)
df['city'].unique()
# Out:
# array(['Bangalore', 'Delhi', 'Mumbai', 'Chennai', 'Kolkata'], dtype=object)

# %%
# To find out data of each city.
df['city'].value_counts()
# Out:
# Bangalore    5887
# Delhi        1501
# Kolkata      1258
# Mumbai       1193
# Chennai       853
# Name: city, dtype: int64

# %%
# Descriptive data of each city.
list(df.groupby('city'))
# Out:
# [('Bangalore',
#               city            area  rooms  bathroom  parking_spaces floor  \
#   0      Bangalore     Brookefield      2         2               1     8
#   2      Bangalore    Haralur Road      3         2               0     -
#   4      Bangalore  Sarjapur  Road      2         2               1     1
#   5      Bangalore  Subramanyapura      2         2               0     1
#   7      Bangalore      Begur Road      3         4               3     2
#   ...          ...             ...    ...       ...             ...   ...
#   10685  Bangalore      HBR Layout      3         3               2     -
#   10686  Bangalore      Chandapura      3         2               1    15
#   10687  Bangalore      Whitefield      1         2               1     9
#   10690  Bangalore     Tumkur Road      3         4               3     4
#   10691  Bangalore    Rajaji Nagar      3         2               1     2
#
# ...

# %% [markdown]
# # Data Analysis

# %%
# Fetching Data of Delhi city only
df[df.city == 'Delhi']
# Out:
#         city                area  rooms  bathroom  parking_spaces floor  \
# 1      Delhi    Rohini sector 16      3         2               2    10
# 6      Delhi   Mansarover Garden      2         1               0     7
# 18     Delhi         Patel Nagar      2         2               1     5
# 19     Delhi    Sector 22 Dwarka      2         2               2     2
# 25     Delhi             Khanpur      2         1               1     9
# ...      ...                 ...    ...       ...             ...   ...
# 10663  Delhi  Safdarjung Enclave      2         2               1    12
# 10664  Delhi       Paschim Vihar      1         1               0     3
# 10666  Delhi         Mayur Vihar      3         1               0     1
# 10673  Delhi   Greater kailash 1      1         1               0     1
# 10675  Delhi    Uttam Nagar west      1         1               0    12
#
#       animal_allowance      furniture  association_tax  rent_amount  \
# ...

# %%
df.query('city == "Delhi"')
# Out:
#         city                area  rooms  bathroom  parking_spaces floor  \
# 1      Delhi    Rohini sector 16      3         2               2    10
# 6      Delhi   Mansarover Garden      2         1               0     7
# 18     Delhi         Patel Nagar      2         2               1     5
# 19     Delhi    Sector 22 Dwarka      2         2               2     2
# 25     Delhi             Khanpur      2         1               1     9
# ...      ...                 ...    ...       ...             ...   ...
# 10663  Delhi  Safdarjung Enclave      2         2               1    12
# 10664  Delhi       Paschim Vihar      1         1               0     3
# 10666  Delhi         Mayur Vihar      3         1               0     1
# 10673  Delhi   Greater kailash 1      1         1               0     1
# 10675  Delhi    Uttam Nagar west      1         1               0    12
#
#       animal_allowance      furniture  association_tax  rent_amount  \
# ...

# %%
df.groupby('city').get_group('Delhi')
# Out:
#         city                area  rooms  bathroom  parking_spaces floor  \
# 1      Delhi    Rohini sector 16      3         2               2    10
# 6      Delhi   Mansarover Garden      2         1               0     7
# 18     Delhi         Patel Nagar      2         2               1     5
# 19     Delhi    Sector 22 Dwarka      2         2               2     2
# 25     Delhi             Khanpur      2         1               1     9
# ...      ...                 ...    ...       ...             ...   ...
# 10663  Delhi  Safdarjung Enclave      2         2               1    12
# 10664  Delhi       Paschim Vihar      1         1               0     3
# 10666  Delhi         Mayur Vihar      3         1               0     1
# 10673  Delhi   Greater kailash 1      1         1               0     1
# 10675  Delhi    Uttam Nagar west      1         1               0    12
#
#       animal_allowance      furniture  association_tax  rent_amount  \
# ...

# %%
# Checking the lowest rent in any area of all cities.

df.sort_values(by = 'total_rent') # ascending order
# Out:
#            city                   area  rooms  bathroom  parking_spaces floor  \
# 436     Kolkata               Kaikhali      1         1               0     -
# 3409      Delhi                  Saket      1         1               1     3
# 1195      Delhi                  Saket      1         1               1     3
# 1746  Bangalore  Raja Rajeshwari Nagar      1         1               0     -
# 4079     Mumbai             Malad West      1         1               0     -
# ...         ...                    ...    ...       ...             ...   ...
# 1707  Bangalore     Vishwapriya Layout      4         5               4     6
# 355   Bangalore         CV Raman Nagar      5         4               2     7
# 2689  Bangalore          Kaggadasapura      1         2               1     6
# 4976    Kolkata           Lake Gardens      1         4               0     4
# 828     Kolkata           Lake Gardens      1         4               0     4
#
# ...

# %%
df.sort_values(by = 'total_rent', ascending = False) # decending order.
# Out:
#            city                   area  rooms  bathroom  parking_spaces floor  \
# 4976    Kolkata           Lake Gardens      1         4               0     4
# 828     Kolkata           Lake Gardens      1         4               0     4
# 2689  Bangalore          Kaggadasapura      1         2               1     6
# 355   Bangalore         CV Raman Nagar      5         4               2     7
# 1707  Bangalore     Vishwapriya Layout      4         5               4     6
# ...         ...                    ...    ...       ...             ...   ...
# 4079     Mumbai             Malad West      1         1               0     -
# 1746  Bangalore  Raja Rajeshwari Nagar      1         1               0     -
# 1195      Delhi                  Saket      1         1               1     3
# 3409      Delhi                  Saket      1         1               1     3
# 436     Kolkata               Kaikhali      1         1               0     -
#
# ...

# %%
# To find lowest rent in any area of Delhi city only
Delhi = df.groupby('city').get_group('Delhi')

# %%
df2 = pd.DataFrame(Delhi)

# %%
df2
# Out:
#         city                area  rooms  bathroom  parking_spaces floor  \
# 1      Delhi    Rohini sector 16      3         2               2    10
# 6      Delhi   Mansarover Garden      2         1               0     7
# 18     Delhi         Patel Nagar      2         2               1     5
# 19     Delhi    Sector 22 Dwarka      2         2               2     2
# 25     Delhi             Khanpur      2         1               1     9
# ...      ...                 ...    ...       ...             ...   ...
# 10663  Delhi  Safdarjung Enclave      2         2               1    12
# 10664  Delhi       Paschim Vihar      1         1               0     3
# 10666  Delhi         Mayur Vihar      3         1               0     1
# 10673  Delhi   Greater kailash 1      1         1               0     1
# 10675  Delhi    Uttam Nagar west      1         1               0    12
#
#       animal_allowance      furniture  association_tax  rent_amount  \
# ...

# %%
df2.sort_values(by = 'total_rent')
# Out:
#        city              area  rooms  bathroom  parking_spaces floor  \
# 1195  Delhi             Saket      1         1               1     3
# 3409  Delhi             Saket      1         1               1     3
# 8662  Delhi   Greater Kailash      1         1               0     4
# 4642  Delhi   East of Kailash      1         1               0     2
# 6011  Delhi   Greater Kailash      1         1               0     4
# ...     ...               ...    ...       ...             ...   ...
# 4436  Delhi   Sector 5 Dwarka      3         4               2    12
# 4576  Delhi      IP Extension      4         4               1     2
# 442   Delhi         SULTANPUR      5         7               4     -
# 4433  Delhi   Panchsheel Park      2         2               1    11
# 6479  Delhi  Uttam Nagar west      1         1               0     1
#
#      animal_allowance      furniture  association_tax  rent_amount  \
# 1195            acept  not furnished                0         1500
# ...

# %%
# Area in which flat is available in Delhi city.

list(df2['area'].unique())
# Out:
# ['Rohini sector 16',
#  'Mansarover Garden',
#  'Patel Nagar',
#  'Sector 22 Dwarka',
#  'Khanpur',
#  'Karol Bagh',
#  'Greater kailash 1',
#  'Dwarka Mor',
#  'Mehrauli',
#  'Vasant Kunj',
#  'Hauz Khas',
#  'Paschim Vihar',
#  'Mahavir Enclave',
#  'Sector 10 Dwarka',
#  'Vasant Vihar',
#  'Greater Kailash II',
#  'Chattarpur',
#  'Sector 12 Dwarka',
#  'Ranjeet Nagar',
#  'Defence Colony',
#  'Punjabi Bagh',
#  'Ismailpur Road',
#  'Uttam Nagar',
#  'Rajinder Nagar',
#  'Ramesh Nagar',
#  'Lajpat Nagar II',
#  'Greater Kailash',
#  'Sector 6 Dwarka',
#  'Uttam Nagar west',
#  'Sector 22 Rohini',
#  'Rohini sector 24',
#  'Malviya Nagar',
#  'Mansa Ram Park',
#  'Kundli',
#  'JJ Colony',
#  'Jangpura',
#  'Bindapur',
#  'Safdarjung Enclave',
#  'Sector 25 Rohini',
#  'Ashok Nagar',
#  'Hari Nagar',
#  'Saket',
#  'Green Park',
#  'Green Park Extension',
#  'Sainik Farms',
#  'SULTANPUR',
#  'Chittaranjan Park',
#  'Delhi',
#  'Badarpur Border',
#  'Noida',
#  'Gulmohar park',
# ...

# %%
# To check flats of 2 rooms and 2 bathrooms in Delhi city.

df2.query('rooms == 2 & bathroom == 2')
# Out:
#         city                area  rooms  bathroom  parking_spaces floor  \
# 18     Delhi         Patel Nagar      2         2               1     5
# 19     Delhi    Sector 22 Dwarka      2         2               2     2
# 61     Delhi         Vasant Kunj      2         2               0     4
# 72     Delhi         Vasant Kunj      2         2               1     3
# 103    Delhi        Vasant Vihar      2         2               1     2
# ...      ...                 ...    ...       ...             ...   ...
# 10419  Delhi          Dwarka Mor      2         2               1     1
# 10451  Delhi       Paschim Vihar      2         2               0     2
# 10608  Delhi       Malviya Nagar      2         2               0     2
# 10649  Delhi         Uttam Nagar      2         2               1     2
# 10663  Delhi  Safdarjung Enclave      2         2               1    12
#
#       animal_allowance      furniture  association_tax  rent_amount  \
# ...

# %%
# To check flats of 2 rooms and 2 bathrooms in Vasant Kunj of Delhi city.

df2.query('rooms == 2 & bathroom == 2 & area == "Vasant Kunj"')
# Out:
#         city         area  rooms  bathroom  parking_spaces floor  \
# 61     Delhi  Vasant Kunj      2         2               0     4
# 72     Delhi  Vasant Kunj      2         2               1     3
# 923    Delhi  Vasant Kunj      2         2               1     2
# 2285   Delhi  Vasant Kunj      2         2               1     4
# 2375   Delhi  Vasant Kunj      2         2               1     8
# 2640   Delhi  Vasant Kunj      2         2               1     1
# 2864   Delhi  Vasant Kunj      2         2               1     4
# 3161   Delhi  Vasant Kunj      2         2               1     4
# 3266   Delhi  Vasant Kunj      2         2               0     5
# 3713   Delhi  Vasant Kunj      2         2               0    13
# 4671   Delhi  Vasant Kunj      2         2               0     5
# 4684   Delhi  Vasant Kunj      2         2               0    10
# 4853   Delhi  Vasant Kunj      2         2               1     9
# ...

# %%
# To find flat with 2 rooms and furniture having rent under 10000 in Delhi.

df2.query('rooms == 2 & furniture == "furnished" & total_rent < 10000' )
# Out:
#         city                     area  rooms  bathroom  parking_spaces floor  \
# 84     Delhi          Mahavir Enclave      2         1               1     8
# 1013   Delhi       Safdarjung Enclave      2         1               1     4
# 1280   Delhi        Greater kailash 1      2         1               0     9
# 1331   Delhi        Greater kailash 1      2         1               1     5
# 1332   Delhi              Jamia Nagar      2         2               1     1
# 1385   Delhi  Delhi Meerut Expressway      2         2               0     2
# 1984   Delhi            Malviya Nagar      2         1               1     3
# 1994   Delhi        Greater kailash 1      2         1               1     2
# 2255   Delhi        Greater kailash 1      2         1               1     5
# 2797   Delhi         Sector 22 Dwarka      2         2               2     3
# 2952   Delhi               Dwarka Mor      2         2               1     7
# ...

# %%
# Top 5 flat with 2 rooms and furniture having rent under 10000 in Delhi.

df2.query('rooms == 2 & furniture == "furnished" & total_rent < 10000' ).head()
# Out:
#        city                area  rooms  bathroom  parking_spaces floor  \
# 84    Delhi     Mahavir Enclave      2         1               1     8
# 1013  Delhi  Safdarjung Enclave      2         1               1     4
# 1280  Delhi   Greater kailash 1      2         1               0     9
# 1331  Delhi   Greater kailash 1      2         1               1     5
# 1332  Delhi         Jamia Nagar      2         2               1     1
#
#      animal_allowance  furniture  association_tax  rent_amount  property_tax  \
# 84              acept  furnished             1590         5880           138
# 1013            acept  furnished             1500         4080            99
# 1280            acept  furnished             1860         4980           126
# 1331            acept  furnished             1290         3450            27
# 1332            acept  furnished             3000         5850           237
#
#       fire_insurance  total_rent
# 84                78        7686
# ...

# %%
# Top 5 Costliest flat in Delhi.
df2.query('rooms == 2 & furniture == "furnished"' ).tail()
# Out:
#         city            area  rooms  bathroom  parking_spaces floor  \
# 10328  Delhi  Defence Colony      2         2               1     6
# 10419  Delhi      Dwarka Mor      2         2               1     1
# 10544  Delhi        Mithapur      2         1               1     9
# 10649  Delhi     Uttam Nagar      2         2               1     2
# 10661  Delhi     Jamia Nagar      2         1               0     -
#
#       animal_allowance  furniture  association_tax  rent_amount  property_tax  \
# 10328            acept  furnished             7500        15000          4251
# 10419            acept  furnished             2850        10500           675
# 10544            acept  furnished             1500         4110           168
# 10649            acept  furnished            12300        22500          1752
# 10661            acept  furnished                0        14850           177
#
#        fire_insurance  total_rent
# 10328             195       26946
# ...

# %%
# Maximam rent in Delhi city
df2['total_rent'].max()
# Out:
# 286830

# %%
# Minimum rent in Delhi city
df2['total_rent'].min()
# Out:
# 1521

# %%
df2.query('rooms == 2 & bathroom == 2')['area'].value_counts()
# Out:
# Uttam Nagar                27
# Dwarka Mor                 24
# Vasant Kunj                18
# Safdarjung Enclave         12
# Chattarpur                  9
#                            ..
# Kundli                      1
# Delhi Meerut Expressway     1
# Sector 25 Rohini            1
# Vasant Vihar                1
# Paschim Vihar               1
# Name: area, Length: 62, dtype: int64
